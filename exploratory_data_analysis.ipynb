# %% [markdown]
# loan default challange dataset(by the reference of the website TOWARDS AI)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data=pd.read_csv('train_sample.csv')
data
# Out:
#         UniqueID  disbursed_amount  ...  NO.OF_INQUIRIES  loan_default
# 0         420825             50578  ...                0             0
# 1         537409             47145  ...                0             1
# 2         417566             53278  ...                0             0
# 3         624493             57513  ...                1             1
# 4         539055             52378  ...                1             1
# ...          ...               ...  ...              ...           ...
# 233149    626432             63213  ...                0             0
# 233150    606141             73651  ...                0             0
# 233151    613658             33484  ...                0             0
# 233152    548084             34259  ...                0             0
# 233153    630213             75751  ...                0             0
#
# [233154 rows x 29 columns]

# %% [markdown]
# IDENTIFICATION OF VARIABLES(ONE OF THE FORWARD STEP FOR EXPLORATORY DATA ANALYSIS)

# %% [markdown]
# Numeric variables have values that describe a measurable quantity as a number, like 'how many' or 'how much'. Therefore numeric variables are quantitative variables. Numeric variables may be further described as either continuous or discrete: A continuous variable is a numeric variabl

# %% [markdown]
# A categorical variable (sometimes called a nominal variable) is one that has two or more categories, but there is no intrinsic ordering to the categories. ... Hair color is also a categorical variable having a number of categories (blonde, brown, brunette, red, etc.)

# %%
data.dtypes
# Out:
# UniqueID                           int64
# disbursed_amount                 float64
# asset_cost                       float64
# ltv                              float64
# branch_id                        float64
# supplier_id                      float64
# manufacturer_id                  float64
# Current_pincode_ID               float64
# Date.of.Birth                     object
# Employment.Type                   object
# DisbursalDate                     object
# State_ID                         float64
# Employee_code_ID                 float64
# MobileNo_Avl_Flag                float64
# Aadhar_flag                      float64
# PAN_flag                         float64
# VoterID_flag                     float64
# Driving_flag                     float64
# Passport_flag                    float64
# PERFORM_CNS.SCORE                float64
# PERFORM_CNS.SCORE.DESCRIPTION     object
# PRI.NO.OF.ACCTS                  float64
# PRI.ACTIVE.ACCTS                 float64
# ...

# %%
data.shape
# Out:
# (60528, 29)

# %%
data.describe()
# Out:
#             UniqueID  disbursed_amount  ...  NO.OF_INQUIRIES  loan_default
# count   60528.000000      60527.000000  ...     60527.000000  60527.000000
# mean   535857.143421      53634.056025  ...         0.197614      0.202273
# std     68745.043494      12015.815159  ...         0.697797      0.401698
# min      4637.000000      13369.000000  ...         0.000000      0.000000
# 25%    475389.750000      46752.500000  ...         0.000000      0.000000
# 50%    535905.500000      53303.000000  ...         0.000000      0.000000
# 75%    596452.500000      59541.500000  ...         0.000000      0.000000
# max    658675.000000     166972.000000  ...        19.000000      1.000000
#
# [8 rows x 25 columns]

# %%
data['loan_default'].value_counts()
# Out:
# 0.0    48284
# 1.0    12243
# Name: loan_default, dtype: int64

# %%
data['branch_id'].nunique()   ##returns a series with several distinct observations in a column
# Out:
# 55

# %%
data['branch_id'].unique()    ##gives u the unique(non-repeated values)
# Out:
# array([ 67.,  78.,  34., 130.,  74.,  11.,   5.,  20.,  63.,  48.,  79.,
#          3.,  42., 142.,  36.,  16., 146., 147.,  65.,   9.,   1., 152.,
#         29.,  10.,  70.,  19.,   7.,  85.,  61.,  17.,   8., 153.,  18.,
#        162.,  68.,  72.,  64.,   2., 160., 251., 103., 104., 120., 136.,
#         77.,  13., 138., 135.,  73., 248.,  15., 165.,  62.,  76., 105.,
#         nan])

# %% [markdown]
# FILTERING BASED ON THE PARTICULAR CONDITIONS

# %%
data[data['Employment.Type']=='Salaried']
# Out:
#        UniqueID  disbursed_amount  ...  NO.OF_INQUIRIES  loan_default
# 0        420825           50578.0  ...              0.0           0.0
# 6        529269           46349.0  ...              0.0           0.0
# 7        510278           43894.0  ...              0.0           0.0
# 9        510980           52603.0  ...              0.0           0.0
# 11       486821           64769.0  ...              1.0           0.0
# ...         ...               ...  ...              ...           ...
# 60437    459441           42169.0  ...              0.0           0.0
# 60438    536552           52803.0  ...              0.0           0.0
# 60439    615893           46771.0  ...              0.0           0.0
# 60440    521864           45175.0  ...              0.0           1.0
# 60441    536546           69097.0  ...              0.0           0.0
#
# [26389 rows x 29 columns]

# %%
data[(data['Employment.Type']=='Salaried') & (data['branch_id']==100)]
# Out:
#         UniqueID  disbursed_amount  ...  NO.OF_INQUIRIES  loan_default
# 192434    620818             58259  ...                0             0
# 192436    433804             56259  ...                0             0
# 192437    648534             59213  ...                0             0
# 192439    627548             74079  ...                0             0
# 192445    530872             61213  ...                0             0
# ...          ...               ...  ...              ...           ...
# 227668    645514             70123  ...                0             0
# 227670    585715             59259  ...                0             0
# 229687    637911             26681  ...                0             0
# 229689    647168             71123  ...                1             0
# 230511    634676             46349  ...                0             0
#
# [96 rows x 29 columns]

# %%
data.value_counts()
# Out:
# UniqueID  disbursed_amount  asset_cost  ltv    branch_id  supplier_id  manufacturer_id  Current_pincode_ID  Date.of.Birth  Employment.Type  DisbursalDate  State_ID  Employee_code_ID  MobileNo_Avl_Flag  Aadhar_flag  PAN_flag  VoterID_flag  Driving_flag  Passport_flag  PERFORM_CNS.SCORE  PERFORM_CNS.SCORE.DESCRIPTION  PRI.NO.OF.ACCTS  PRI.ACTIVE.ACCTS  PRI.OVERDUE.ACCTS  PRI.CURRENT.BALANCE  PRI.SANCTIONED.AMOUNT  PRI.DISBURSED.AMOUNT  NO.OF_INQUIRIES  loan_default
# 671084    30034             76960       41.58  8          14823        45               5244                25-12-93       Self employed    31-10-18       3         3490              1                  1            0         0             0             0              0                  No Bureau History Available    0                0                 0                  0                    0                      0                     0                0               1
# ...

# %%
data.isnull().sum()
# Out:
# UniqueID                            0
# disbursed_amount                    0
# asset_cost                          0
# ltv                                 0
# branch_id                           0
# supplier_id                         0
# manufacturer_id                     0
# Current_pincode_ID                  0
# Date.of.Birth                       0
# Employment.Type                  7661
# DisbursalDate                       0
# State_ID                            0
# Employee_code_ID                    0
# MobileNo_Avl_Flag                   0
# Aadhar_flag                         0
# PAN_flag                            0
# VoterID_flag                        0
# Driving_flag                        0
# Passport_flag                       0
# PERFORM_CNS.SCORE                   0
# PERFORM_CNS.SCORE.DESCRIPTION       0
# PRI.NO.OF.ACCTS                     0
# PRI.ACTIVE.ACCTS                    0
# PRI.OVERDUE.ACCTS                   0
# PRI.CURRENT.BALANCE                 0
# ...

# %%
pd.to_datetime(data['Date.of.Birth'])   ##converts unappropriate date of birth to appropriate
# Out:
# 0        1984-01-01
# 1        1985-07-31
# 2        1985-08-24
# 3        1993-12-30
# 4        1977-09-12
#             ...
# 233149   1988-01-08
# 233150   1988-05-12
# 233151   1976-01-06
# 233152   1994-03-26
# 233153   1984-02-18
# Name: Date.of.Birth, Length: 233154, dtype: datetime64[ns]

# %%
data['ltv'].astype('int')  ### converts the data type
# Out:
# 0         89
# 1         73
# 2         89
# 3         88
# 4         88
#           ..
# 233149    60
# 233150    74
# 233151    48
# 233152    49
# 233153    66
# Name: ltv, Length: 233154, dtype: int64

# %%
data.dtypes
# Out:
# UniqueID                           int64
# disbursed_amount                   int64
# asset_cost                         int64
# ltv                              float64
# branch_id                          int64
# supplier_id                        int64
# manufacturer_id                    int64
# Current_pincode_ID                 int64
# Date.of.Birth                     object
# Employment.Type                   object
# DisbursalDate                     object
# State_ID                           int64
# Employee_code_ID                   int64
# MobileNo_Avl_Flag                  int64
# Aadhar_flag                        int64
# PAN_flag                           int64
# VoterID_flag                       int64
# Driving_flag                       int64
# Passport_flag                      int64
# PERFORM_CNS.SCORE                  int64
# PERFORM_CNS.SCORE.DESCRIPTION     object
# PRI.NO.OF.ACCTS                    int64
# PRI.ACTIVE.ACCTS                   int64
# ...

# %% [markdown]
# UNIVARIATE ANALYSIS(FOR THE DATA HAVING SINGLE CHARACTERSTICS)

# %%
plt.hist(x='ltv',bins=20,data=data)      ##bins parameter contains integer or sequence or strings
plt.grid()
plt.show()

# %%
plt.hist(x='asset_cost',bins=200,data=data) 
plt.show()

# %%
BOX PLOT---TO IDENTIFY THE OUTLIERS IN THE DATASET

# %%
import seaborn as sb

# %%
sb.boxplot(y='disbursed_amount',data=data)

# %%
print(data.boxplot(column='disbursed_amount'))  ##the circles represents the outliers in that "distributed_amount" column
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
